# %% [markdown]
# # Deep learning from scratch: homework 1

# %% [markdown]
# ### Python 3 / Jupyter install instructions

# %% [markdown]
# For those having trouble getting Jupyter notebook up and running I recommend installing the Anaconda Python 3 distribution - which you can [find here](https://www.anaconda.com/download/).  The basic distribution includes a number of useful libraries - including numpy, matplotlib, and Jupyter itself - and makes it easier to install additional libraries as well.  Just make sure you download the Python 3.6 distribution if you do this.
#
# You will also need the automatic differentiator [autograd](https://github.com/HIPS/autograd) - you can install this package via your terminal by typing
#
# ``pip install autograd``

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 1. </span> Getting to know autograd

# %% [markdown]
# Time to add in a powerful gradient calculator that works well with the numpy library.  [Click here to view the github repo](https://github.com/HIPS/autograd) - download its contents to your machine.

# %% [markdown]
# When using autograd for automatic differentiation, be sure to employ autograd's version of numpy - so that the automatic differentiator can correctly parse your input functions.

# %%
# import statement for autograd wrapped numpy
import autograd.numpy as np

# %% [markdown]
# There are two standard ways of defining functions in Python.  First the the standard named Python function like below

# %%
# a named Python function
def sin(w):
    return np.sin(w)

# %% [markdown]
# WIth this declaration Python now understands 'sin' as its own function, so it can be called as follows.

# %%
# how to use the 'sin' function
w_val = 1.0   # a test input for our 'sin' function
g_val = sin(w_val)
print (g_val)
# Out:
# 0.8414709848078965

# %% [markdown]
# You can also create 'anonymous' functions in Python (functions unconnected to a name) by using the ``lambda`` command.  We can produce the same function using lambda as shown below.

# %%
# how to use 'lambda' to create an anonymous function
g = lambda w: np.sin(w)

# %% [markdown]
# We can then use it with a test value as shown below.

# %%
# how to use the 'sin' function
w_val = 1.0   # a test input for our 'sin' function
g_val = g(w_val)
print (g_val)
# Out:
# 0.8414709848078965

# %% [markdown]
# We can visualize this function by using ``matplotlib`` assets, as shown below.

# %%
# the import statement for matplotlib
import matplotlib.pyplot as plt

# %%
# create a sample of points to plot over 
w_vals = np.linspace(-5,5,200)

# evaluate the function over each of these values - one can use an explicit for-loop here instead of a list comprehension
g_vals = [g(v) for v in w_vals]

# plot
fig, ax = plt.subplots(1, 1, figsize=(6,3))
ax.plot(w_vals,g_vals)
plt.show()

# %% [markdown]
# Using autograd we can then compute the gradient function here.  We show the proper import statement and manner of using this calculator below.Mm

# %%
# import statment for gradient calculator
from autograd import grad

# %%
# create the gradient function of g --> nabla_g
nabla_g = grad(g)

# %% [markdown]
# The gradient function can be evaluated like the original - as shown in the next cell.

# %%
# evaluate the gradient function at a point
w_val = 1.0
nabla_g(1.0)
# Out:
# 0.5403023058681398

# %% [markdown]
# Now we can plot the gradient along with the original function, which we do in the next cell.

# %%
# create space over which to evaluate function and gradient
w_vals = np.linspace(-5,5,100)

# evaluate gradient over input range
g_vals = [g(v) for v in w_vals]
grad_vals = [nabla_g(v) for v in w_vals]

# create figure
fig, ax = plt.subplots(1, 1, figsize=(6,3))

# plot function and gradient values
ax.plot(w_vals,g_vals)
ax.plot(w_vals,grad_vals)
ax.legend(['func','derivative'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 1. </span> Python class refresher

# %% [markdown]
# Roll up the Python functions provided for you in the previous example to make a Python class for computing and viewing single input derivatives called ``GradViewer``.  Instances should be initialized with the input function to differentiate, and the gradient function can be computed on initialization as well.
#
# When complete you should be able to successfully run the cell below.

# %%
class GradViewer():

    def __init__(self, fn):
        self.nabla_c = grad(fn)
        self.w_cube_vals = np.linspace(-5,5,200)
        # func
        self.g_cube_vals = [fn(v) for v in self.w_cube_vals]
        # deriv
        self.grad_cube_vals = [self.nabla_c(v) for v in self.w_cube_vals]

    def plot_it(self):
        fig, ax = plt.subplots(1, 1, figsize=(6,3))
        # func
        ax.plot(self.w_cube_vals, self.g_cube_vals)
        # deriv
        ax.plot(self.w_cube_vals, self.grad_cube_vals)
        ax.legend(['func','derivative'],loc='center left', bbox_to_anchor=(1, 0.5))
        plt.show()

# %%
# test function input
def my_function(w):
    y = np.sin(w**3)
    return y

# create instance, inputting function on creation
test = GradViewer(my_function)

# plot this derivative and original function
test.plot_it()

# %% [markdown]
# Next with your derivative viewer complete - visualize the following function and its derivative using the cell above.
#
# \begin{equation}
# g(w) = \sum_{n = 0}^{10} \text{cos}(n\cdot w)
# \end{equation}

# %%
# test function input
def new_function(w):
    n = np.linspace(0, 10, 10)
    y = sum(np.cos(n*w))
    return y

# create instance, inputting function on creation
test_new = GradViewer(new_function)

# plot this derivative and original function
test_new.plot_it()

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 2. </span> Python class refresher part 2

# %% [markdown]
# Extend the class you put together in exercise 1 into a new class called ``OrderViewer`` that can compute a higher order derivative of any desired order of an input function, and plots both.  Make a new function for this class ``compute_it`` that takes in the desired ``order`` and computes this order derivative.
#
# When complete you should be able to successfully run the cell below.

# %%
class OrderViewer(GradViewer):

    def __init__(self, fn):
        super().__init__(fn)

        self.nabla_c = grad(fn)
        self.w_cube_vals = np.linspace(-5,5,200)
        # func
        self.g_cube_vals = [fn(v) for v in self.w_cube_vals]
        # deriv
        self.grad_cube_vals = [self.nabla_c(v) for v in self.w_cube_vals]
    
    def compute_it(self, order):
        if order != 1:
            order = order - 1
            while(order > 0):
                # deriv in grad_cube_vals
                self.grad_cube_vals = [self.nabla_c(v) for v in self.grad_cube_vals]
                order = order - 1

# %%
# test function input
def my_function(w):
    y = w**2
    return y

# create instance, inputting function on creation
test = OrderViewer(my_function)

# compute desired order derivative
test.compute_it(order = 3)

# plot this derivative and original function
test.plot_it()

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 3. </span>  A generic gradient descent function

# %% [markdown]
# Adjust the gradient descent code below we saw in class to record the weights at each step of algorithm (instead of the best weights) and return the entire weight history.  Remember here the inputs are
#
# - g: the input function to perform gradient descent on
# - alpha: the steplength parameter
# - max_its: the number of gradient descent steps to take
# - w: the initial point

# %% [markdown]
# Your version of the ``gradient_descent`` below should return a history of weights recorded at each step called ``weight_history``.

# %%
# gradient descent function - inputs: g (input function), alpha (steplength parameter), max_its (maximum number of iterations), w (initialization)
def gradient_descent(g, alpha, max_its, w):
    # compute the gradient of our input function - note this is a function too!
    gradient = grad(g)

    # run the gradient descent loop
#     best_w = w        # weight we return, should be the one providing lowest evaluation
#     best_eval = g(w)       # lowest evaluation yet
    entire_history = [w]
    
    for k in range(max_its):
        # evaluate the gradient
        grad_eval = gradient(w)

        # take gradient descent step
        w = w - alpha*grad_eval
        entire_history.append(w)

        # return only the weight providing the lowest evaluation
#         test_eval = g(w)
#         if test_eval < best_eval:
#             best_eval = test_eval
#             best_w = w
            
    return entire_history

# %% [markdown]
# Next run gradient descent to minimize the following function
#
# \begin{equation}
# g(w) = \frac{1}{50}\left(w^4 + w^2 + 10w\right)
# \end{equation}
#
# with an initial point $w_0 = 2$, steplength parameter $\alpha = 0.1$, and 2000 iterations.

# %%
# create the input function
g = lambda w: 1/float(50)*(w**4 + w**2 + 10*w)   # try other functions too!  Like g = lambda w: np.cos(2*w) , g = lambda w: np.sin(5*w) + 0.1*w**2, g = lambda w: np.cos(5*w)*np.sin(w)

# run gradient descent
weight_history = gradient_descent(g = g,
                                  alpha = 10**-1,
                                  max_its = 2000,
                                  w = 2.0)
weight_history
# Out:
# [2.0,
#  1.908,
#  1.824799957504,
#  1.748889621318221,
#  1.679100623893497,
#  1.6145120543687588,
#  1.5543862740516654,
#  1.4981241000128434,
#  1.4452327755808814,
#  1.395302608609765,
#  1.347989622895199,
#  1.303002467414822,
#  1.260092395988194,
#  1.219045497637175,
#  1.1796766013289182,
#  1.1418244431694085,
#  1.1053477971656158,
#  1.070122349711862,
#  1.0360381540521417,
#  1.0029975413375403,
#  0.9709133943185221,
#  0.9397077114077564,
#  0.9093104050237678,
#  0.8796582903068714,
#  0.850694229559548,
#  0.822366404866195,
#  0.7946276968400683,
#  0.7674351517261606,
#  0.7407495224495407,
#  0.7145348718552511,
#  0.688758228499428,
#  0.6633892870431616,
#  0.6384001466627518,
#  0.6137650819927147,
#  0.5894603420151976,
#  0.565463973043235,
#  0.541755662548115,
#  0.5183166010785846,
#  0.4951293599318519,
#  0.4721777825792921,
#  0.4494468881361504,
#  0.4269227854045443,
#  0.4045925962208697,
#  0.3824443870089395,
#  0.3604671075841893,
#  0.3386505363764501,
#  0.3169852313426961,
#  0.2954624859297684,
#  0.27407428952278096,
#  0.25281329187974894,
#  0.23167277110861423,
#  0.210646604790674,
#  0.18972924389562543,
#  0.1689156891690021,
#  0.148201469703539,
#  0.12758262343266633,
#  0.1070556793075094,
#  0.08661764093897929,
#  0.06626597150422579,
#  0.045998579732279936,
#  0.025813806797475462,
#  0.005710413961502937,
#  -0.014312429184022313,
#  -0.03425515601257774,
#  -0.054117813824220776,
#  -0.07390007459383953,
#  -0.09360124561833522,
#  -0.1132202801671029,
#  -0.13275578823257475,
#  -0.15220604747007893,
#  -0.17156901440875277,
#  -0.19084233600765363,
#  -0.21002336162346813,
#  -0.22910915544828123,
#  -0.24809650946769263,
#  -0.2669819569811381,
#  -0.28576178671757796,
#  -0.3044320575707618,
#  -0.32298861396908285,
#  -0.3414271018856388,
#  -0.3597429854845555,
#  -0.3779315643899741,
#  -0.39598799155441755,
#  -0.41390729169362306,
#  -0.4316843802454458,
#  -0.4493140828012044,
#  -0.46679115494895745,
#  -0.4841103024597836,
#  -0.5012662017402937,
#  -0.5182535204674481,
#  -0.5350669383153889,
#  -0.5517011676785285,
#  -0.5681509742906599,
#  -0.5844111976364431,
#  -0.6004767710493606,
#  -0.6163427413891566,
#  -0.6320042881919393,
#  -1.2347728250532284,
#  -1.2347728250532313,
#  -1.234772825053234,
#  -1.2347728250532366,
#  -1.234772825053239,
#  -1.2347728250532415,
#  -1.2347728250532437,
#  -1.234772825053246,
#  -1.234772825053248,
#  -1.23477282505325,
#  -1.234772825053252,
#  -1.2347728250532537,
#  -1.2347728250532555,
#  -1.2347728250532573,
#  -1.2347728250532588,
#  -1.2347728250532604,
#  -1.234772825053262,
#  -1.2347728250532632,
#  -1.2347728250532646,
#  -1.234772825053266,
#  -1.2347728250532672,
#  -1.2347728250532684,
#  -1.2347728250532695,
#  -1.2347728250532706,
#  -1.2347728250532717,
#  -1.2347728250532728,
#  -1.2347728250532737,
#  -1.2347728250532746,
#  -1.2347728250532755,
#  -1.2347728250532763,
#  -1.2347728250532772,
#  -1.2347728250532781,
#  -1.2347728250532788,
#  -1.2347728250532795,
#  -1.2347728250532801,
#  -1.2347728250532808,
#  -1.2347728250532815,
#  -1.2347728250532821,
#  -1.2347728250532828,
#  -1.2347728250532835,
#  -1.234772825053284,
#  -1.2347728250532843,
#  -1.2347728250532848,
#  -1.2347728250532852,
#  -1.2347728250532857,
#  -1.2347728250532861,
#  -1.2347728250532866,
#  -1.234772825053287,
#  -1.2347728250532874,
#  -1.234772825053288,
#  -1.2347728250532883,
#  -1.2347728250532888,
#  -1.2347728250532892,
#  -1.2347728250532894,
#  -1.2347728250532897,
#  -1.23477282505329,
#  -1.2347728250532901,
#  -1.2347728250532903,
#  -1.2347728250532906,
#  -1.2347728250532908,
#  -1.234772825053291,
#  -1.2347728250532912,
#  -1.2347728250532914,
#  -1.2347728250532917,
#  -1.234772825053292,
#  -1.2347728250532921,
#  -1.2347728250532923,
#  -1.2347728250532926,
#  -1.2347728250532928,
#  -1.234772825053293,
#  -1.2347728250532932,
#  -1.2347728250532934,
#  -1.2347728250532937,
#  -1.2347728250532939,
#  -1.234772825053294,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  -1.2347728250532943,
#  ...]

# %% [markdown]
# Create a Python function that takes in the weight history created by gradient descent and plots the cost function history associated with this run.  A wrapper for this is provided below

# %%
# cost function history plotter
def cost_history(weight_history,g):
    # loop over weight history and compute associated cost function history at each step
    g_hist = [g(v) for v in weight_history]
    
    # plot cost function history
    fig, ax = plt.subplots(1, 1, figsize=(7,4))
    ax.plot(range(len(weight_history)), g_hist)
    plt.show()

# %% [markdown]
# Now use ``cost_history`` above to plot your cost function history.

# %%
# use cost_history plotter
cost_history(weight_history,g)

# %% [markdown]
# What is the weight associated with the smallest cost function value on your run of gradient descent?  Make sure it is close to the true solution at
#
# \begin{equation}
# w = \frac{\sqrt[\leftroot{-2}\uproot{2}3]{\sqrt[\leftroot{-2}\uproot{2}]{2031} - 45}}{6^{\frac{2}{3}}} - \frac{1}{\sqrt[\leftroot{-2}\uproot{2}3]{6\left(\sqrt[\leftroot{-2}\uproot{2}]{2031} - 45\right)}}
# \end{equation}

# %% [markdown]
# # ANSWER:
#
# The value of the above expression is roughly w = -1.2347728251.
#
# The weight associated with the smallest cost function from above is roughly -1.2347728250532943.

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 4. </span>  Apply gradient descent to minimize the Least Squares cost for linear regression on a low dimensional dataset

# %% [markdown]
# In this exercise you will perform gradient descent to minimize the Least Squares cost function for linear regression, using the following toy data to de-bug your work.

# %%
# data input
csvname = '2d_linregress_data.csv'
data = np.loadtxt(csvname, delimiter = ',')

# %% [markdown]
# The first and second columns of ``data`` contain the input and output respectively.  This dataset is scatter plot in the next cell.

# %%
# scatter plot the input data
fig, ax = plt.subplots(1, 1, figsize=(4,4))
ax.scatter(data[:,0],data[:,1],color = 'k',edgecolor = 'w')
plt.show()

# %% [markdown]
# Since we have a gradient descent function (from e.g., the last exercise) all we need to do construct a Least Squares cost function for linear regression.  We did this in class - see below!

# %%
# form the input/output data vectors
x = data[:,:-1]
y = data[:,-1]

# least squares cost function for linear regression
def least_squares(w):
    cost = 0
    for p in range(len(y)):
        # get pth input/output pair
        x_p = x[p]
        y_p = y[p]
        
        # form linear combination
        c_p = w[0] + w[1]*x_p
        
        # add least squares for this datapoint
        cost += (c_p - y_p)**2
        
    return cost

# %% [markdown]
# We can test ``least_squares`` by plugging in an input weight and see the returned cost function value, as illustrated below.

# %%
# try out least squares function
w = np.asarray([1.5,1.5])
least_squares(w)[0]
# Out:
# 149.60536283826102

# %% [markdown]
# With your Least Squares cost function defined its time to run gradient descent for a maximum of 500 iterations beginning at the point $w_0 = \begin{bmatrix} 1.5 \\ 1.5\end{bmatrix}$.  It will be up to you to find a reasonable steplength value $\alpha$ so that the best weights you can find for a run of gradient descent provide a line that fits the data well.

# %%
# run gradient descent
w = np.asarray([1.5,1.5])

weight_history1 = gradient_descent(g = least_squares,
                                   alpha = 0.1,
                                   max_its = 500,
                                   w = w)
weight_history2 = gradient_descent(g = least_squares,
                                   alpha = 0.0001,
                                   max_its = 500,
                                   w = w)
weight_history3 = gradient_descent(g = least_squares,
                                   alpha = 0.00002,
                                   max_its = 500,
                                   w = w)
weight_history4 = gradient_descent(g = least_squares,
                                   alpha = 0.000002,
                                   max_its = 500,
                                   w = w)
# Out:
# /Users/ikhlas/anaconda3/lib/python3.6/site-packages/autograd/tracer.py:48: RuntimeWarning: overflow encountered in add
#   return f_raw(*args, **kwargs)
# /Users/ikhlas/anaconda3/lib/python3.6/site-packages/autograd/tracer.py:48: RuntimeWarning: overflow encountered in power
#   return f_raw(*args, **kwargs)
# /Users/ikhlas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in subtract
#   app.launch_new_instance()

# %% [markdown]
# You should do this by trying a particular value of $\alpha$, running gradient descent, and plotting the associated Mean Squared Error (MSE) for every weight in your gradient descent history (remember: to compute the MSE simply divide the Least Squares cost by the number of datapoints).  You should show the histories of 3 choices for $\alpha$ you tried.  Feel free to use any of the functionality from previous exercises here.  A wrapper for your MSE calculator has been provided in the next cell.

# %%
# MSE history plotter
def MSE(weight_history,g):
    # loop over weight history and compute the MSE at each step o gradient descent

    # mse = lsc / #dp
    # lsc = g(v)
    # #dp = (np.shape(weight_history)[0])
    calc_mse = [g(v)/(np.shape(weight_history)[0]) for v in weight_history]
    
    # plot cost function history
    fig, ax = plt.subplots(1, 1, figsize = (7,4))
    ax.plot(range(len(weight_history)), calc_mse)
    plt.show()

MSE(weight_history1, least_squares)
MSE(weight_history2, least_squares)
MSE(weight_history3, least_squares)
MSE(weight_history4, least_squares)
# Out:
# /Users/ikhlas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in add
# /Users/ikhlas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in square

# %% [markdown]
# # Please Wait!
#
# The above code takes about 10 seconds to load, but I did provide and graph 4 (not 3) unique weight histories!

# %% [markdown]
# In the next cell we plot the line associated with our initial point on top of the data - you can use this functionality to check if your weights provide a good-fitting line

# %%
# our initial weights
w = np.asarray([1.5,1.5])

# check last
w1 = weight_history1[-1]
w2 = weight_history2[-1]
w3 = weight_history3[-1]
w4 = weight_history4[-1]

# scatter plot the input data
fig, ax = plt.subplots(1, 1, figsize=(6,6))
ax.scatter(data[:,0],data[:,1],color = 'k',edgecolor = 'w')

# fit a trend line
x_vals = np.linspace(0,1,200)
#y_vals0 = w[0] + w[1]*x_vals
y_vals1 = w1[0] + w1[1]*x_vals
y_vals2 = w2[0] + w2[1]*x_vals
y_vals3 = w3[0] + w3[1]*x_vals
y_vals4 = w4[0] + w4[1]*x_vals
#ax.plot(x_vals,y_vals0,color = 'r')
ax.plot(x_vals,y_vals1,color = 'b')
ax.plot(x_vals,y_vals2,color = 'r')
ax.plot(x_vals,y_vals3,color = 'g')
ax.plot(x_vals,y_vals4,color = 'c')
ax.legend(['weight_history1','weight_history2','weight_history3','weight_history4'],
          loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 5. </span> Use linear regression to fit to a high dimensional dataset

# %% [markdown]
# The next Python cell loads in a dataset of 100 input/output pairs from a 10 dimensional dataset.  This dataset was constructed by randomly sampling a 10-dimensional hyperplane, so using linear regression we should be able to find a good linear fit to it.

# %%
# load in dataset
data = np.loadtxt('highdim_linregress_data.csv',delimiter = ',')

# form the input/output data vectors
x = data[:,:-1]
y = data[:,-1]

# %% [markdown]
# In the next cell - expand on the linear regression function provided in the previous exercise so that it can handle with $N=10$ dimensional data.

# %%
# least squares cost function for linear regression
def least_squares(w):
    cost = 0
    for p in range(len(y)):
        # get pth input/output pair
        # HERE! CHANGE   x[p]   to   np.reshape(x[p,:],[np.shape(x)[1], 1])
        # required help
        x_p = np.reshape(x[p,:],[np.shape(x)[1],1])
        y_p = y[p]

        # form linear combination
        # HERE! CHANGE   w[1]*x_p   to   np.dot(w[1:].T, x_p)
        # required help
        c_p = w[0] + np.dot(w[1:].T,x_p)
        
        # add least squares for this datapoint
        cost += (c_p - y_p)**2
    return cost[0][0]

# %% [markdown]
# You can test your implementation with input set of weights of all ones.  When you do this you should get the output value printed in the Python cell below.

# %%
# produce input and input into Least Squares cost function
w = np.ones((11,1))
print (least_squares(w))
# Out:
# 7917.979520370183

# %% [markdown]
# Now run gradient descent for up to 1000 iterations to minimize the Least Squares cost function on this dataset.  You can use a random set of weights as your initialization provided in the next cell.  Use the MSE printout to determine a good value of $\alpha$ where you reach an MSE value of 1 or smaller.

# %%
# run gradient descent
w = np.random.randn(np.shape(x)[1]+1,1)
weight_history = gradient_descent(g = least_squares,
                                  alpha = .0025,
                                  max_its = 100,
                                  w = w)

# %% [markdown]
# With $\alpha$ chosen well you should be able to reach this threshold even after just 100 iterations, as shown below.

# %%
# use cost_history plotter
MSE(weight_history, least_squares)
